# %% [markdown]
# # Practice: spatial data

# %%
# !curl -s -o pyproject.toml https://raw.githubusercontent.com/gboeing/ppd534/refs/heads/main/pyproject.toml && uv pip install -q -r pyproject.toml

# %%
import geopandas as gpd
import pandas as pd

# %%
# load the CA census tracts shapefile we used in the lecture as a dataframe
# check its crs attribute: what is its value?

# %%
gdf = gpd.read_file(
    "https://raw.githubusercontent.com/gboeing/ppd534/main/data/tl_2017_06_tract/tl_2017_06_tract.shp"
)

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# load the rental listings CSV file we used in the lecture as a GeoDataFrame
# remember the steps: load it as a pandas dataframe, then create the geometries
# then turn it into a GeoDataFrame, then set the CRS attribute to EPSG:4326

# %%
df = pd.read_csv("https://raw.githubusercontent.com/gboeing/ppd534/main/data/listings-la_oc_vc.csv")

# %%
geometry = gpd.points_from_xy(x=df["longitude"], y=df["latitude"])

# %%
gdf_listings = gpd.GeoDataFrame(df, geometry=geometry, crs="epsg:4326")
gdf_listings.shape
# Out:
# (1097, 6)

# %%
# project the census tracts GeoDataFrame to the same CRS as the rental listings GeoDataFrame
# then verify their CRSs are equal to each other

# %%
gdf = gdf.to_crs(gdf_listings.crs)
gdf.crs == gdf_listings.crs
# Out:
# True

# %%
# get the subset of tracts that do not intersect any of the rental listings

# %%
unified_listings = gdf_listings["geometry"].union_all()
type(unified_listings)
# Out:
# shapely.geometry.multipoint.MultiPoint

# %%
mask = gdf.intersects(unified_listings)

# %%
gdf[~mask].shape
# Out:
# (7401, 13)

# %%
# get the subset of rental listings that are within LA county

# %%
agg = {"ALAND": "sum", "AWATER": "sum"}

# %%
gdf_counties = gdf.dissolve("COUNTYFP", aggfunc=agg)
gdf_counties
# Out:
#                                                    geometry        ALAND  \
# COUNTYFP
# 001       POLYGON ((-122.32792 37.7812, -122.32864 37.78...   1909616630
# 003       POLYGON ((-120.07333 38.70109, -120.07324 38.7...   1912292631
# 005       POLYGON ((-120.54182 38.42258, -120.54237 38.4...   1539933576
# 007       POLYGON ((-122.00127 39.57686, -122.00109 39.5...   4238438196
# 009       POLYGON ((-120.37616 38.14225, -120.37615 38.1...   2641829199
# 011       POLYGON ((-121.93915 39.13606, -121.93901 39.1...   2980332860
# 013       POLYGON ((-122.28848 37.89792, -122.28887 37.8...   1857310903
# 015       POLYGON ((-124.21526 41.99845, -124.21199 41.9...   2606117992
# 017       POLYGON ((-120.21491 38.6285, -120.21532 38.62...   4423290535
# 019       POLYGON ((-119.95893 36.25553, -119.95892 36.2...  15431410219
# 021       POLYGON ((-121.99716 39.66567, -121.9965 39.66...   3403149421
# 023       POLYGON ((-124.08071 40.00196, -124.12614 40.0...   9241251740
# 025       POLYGON ((-115.66236 32.65233, -115.66818 32.6...  10817291631
# 027       POLYGON ((-117.2663 37.0451, -117.26605 37.044...  26368508430
# 029       POLYGON ((-119.4727 34.92126, -119.4727 34.922...  21062393794
# 031       POLYGON ((-120.30646 35.91389, -120.30417 35.9...   3598593366
# 033       POLYGON ((-122.73388 38.77192, -122.73416 38.7...   3254348631
# 035       POLYGON ((-119.99566 40.40219, -119.99566 40.4...  11761615611
# 037       MULTIPOLYGON (((-118.94449 34.04664, -118.9444...  10510588451
# 039       POLYGON ((-120.16953 36.80355, -120.17001 36.8...   5534850492
# 041       POLYGON ((-122.47362 37.83193, -122.47417 37.8...   1347976832
# 043       POLYGON ((-119.87798 37.32401, -119.87839 37.3...   3752472156
# 045       POLYGON ((-123.24382 38.80849, -123.25112 38.8...   9081426673
# 047       POLYGON ((-121.2452 37.03224, -121.24454 37.03...   5012175320
# 049       POLYGON ((-120.15924 41.9946, -120.15895 41.99...  10140960164
# 051       POLYGON ((-118.91726 37.55034, -118.91776 37.5...   7896838493
# 053       POLYGON ((-121.35277 35.7952, -121.35415 35.79...   8496680819
# 055       POLYGON ((-122.29531 38.15522, -122.29681 38.1...   1938165958
# 057       POLYGON ((-120.98945 39.11117, -120.98962 39.1...   2480587331
# 059       POLYGON ((-118.11601 33.74238, -118.11565 33.7...   2048392529
# 061       POLYGON ((-121.29282 38.72143, -121.29342 38.7...   3644244131
# 063       POLYGON ((-120.49308 39.70661, -120.49317 39.7...   6612400919
# 065       POLYGON ((-117.47457 33.70381, -117.48923 33.7...  18664542308
# 067       POLYGON ((-121.8548 38.07254, -121.85291 38.07...   2499039655
# 069       POLYGON ((-121.48351 36.76468, -121.48392 36.7...   3596588882
# 071       POLYGON ((-117.65533 33.92116, -117.65532 33.9...  51948123813
# 073       POLYGON ((-117.18914 32.5299, -117.20492 32.52...  10898787530
# 075       MULTIPOLYGON (((-122.47153 37.70833, -122.4717...    121485107
# 077       POLYGON ((-121.55686 37.63553, -121.55686 37.6...   3606190671
# 079       POLYGON ((-120.65985 34.97968, -120.69206 34.9...   8548552397
# 081       POLYGON ((-122.58302 37.60195, -122.58017 37.6...   1161757245
# 083       MULTIPOLYGON (((-120.64861 34.9741, -120.64786...   7084000622
# 085       POLYGON ((-122.044 37.20094, -122.04397 37.201...   3344209919
# 087       POLYGON ((-121.82352 36.84801, -121.83499 36.8...   1152967426
# 089       POLYGON ((-122.28498 40.37643, -122.28565 40.3...   9778230094
# 091       POLYGON ((-121.0582 39.53704, -121.05816 39.53...   2468694586
# 093       POLYGON ((-122.57268 41.36798, -122.57309 41.3...  16261933292
# 095       POLYGON ((-122.22242 38.06067, -122.22456 38.0...   2128347201
# 097       POLYGON ((-122.93673 38.31152, -122.9367 38.31...   4081450561
# 099       POLYGON ((-121.45726 37.28406, -121.4571 37.28...   3874634688
# 101       POLYGON ((-121.9431 39.18476, -121.94218 39.18...   1560275634
# 103       POLYGON ((-122.17892 39.79744, -122.17952 39.7...   7638228772
# 105       POLYGON ((-123.54446 40.34734, -123.54446 40.3...   8234265086
# 107       POLYGON ((-119.05368 35.79063, -119.05728 35.7...  12494838453
# 109       POLYGON ((-120.65255 37.83346, -120.65229 37.8...   5752079368
# 111       MULTIPOLYGON (((-119.61453 33.3148, -119.6093 ...   4773302741
# 113       POLYGON ((-121.7144 38.53739, -121.71464 38.53...   2628256658
# 115       POLYGON ((-121.61011 39.05789, -121.61008 39.0...   1636913850
#
#               AWATER
# COUNTYFP
# 001        216916717
# 003         12557304
# 005         29470568
# 007        105310997
# 009         43797662
# 011         14608869
# 013        225193562
# 015        578742645
# 017        203328338
# 019        137339029
# 021         33704225
# 023       1254039383
# 025        790230304
# 027        119088140
# 029         78770534
# 031          5453080
# 033        188852161
# 035        463426050
# 037       1794793532
# 039         42012923
# 041        797029137
# 043         36225644
# 045        962946204
# 047        112509475
# 049        745420669
# 051        214695673
# 053       1270736099
# 055        104249021
# 057         41531993
# 059        406915886
# 061        246575767
# 063        156387635
# 065        250588224
# 067         76217822
# 069          4721397
# 071        123845007
# 073        822557348
# 075        479107241
# 077         89046837
# 079        815578711
# 081        757313941
# 083       2729814515
# 085         33276429
# 087        419570389
# 089        186479466
# 091         23299110
# 093        179149824
# 095        218679972
# 097        497495823
# 099         46384540
# 101         15717389
# 103         33767784
# 105         73407949
# 107         37259234
# 109        138722711
# 111        946030569
# 113         22688556
# 115         31057914

# %%
# project the listings to a meter-based projected coordinate system of your choosing
# then buffer the listings by 1km

# %%
# spatial join the (all) rental listings GeoDataFrame to the (all) tracts GeoDataFrame
# to attach tract-level census variables to each rental listing

# %%
# scatter plot the joined GeoDataFrame's rental listing asking rent vs tract-level
# median household income: do you see any pattern?

# %%
# get the subset of tracts that are in LA county and map them colored by median home value
# give it a legend and adjust the map styling to make it clean and interpretable
